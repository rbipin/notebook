# %%
import pandas as pd
import boto3
from boto3.dynamodb.conditions import Key
import simplejson as json
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

class Client:
  def __init__(self, clientId, gcid, ssn, firstName, lastName, isPrimary, isActive):
    self.clientId = clientId
    self.gcid = gcid
    self.ssn = ssn
    self.firstName = firstName
    self.lastName = lastName
    self.isPrimary = isPrimary
    self.isActive = isActive

class RemoveDups:
  def __init__(self, fileName):
    self.fileName = fileName
    
  def start_cleanup(self):
    print('Starting Clean up Process on List')
    loansWithDuplicates = []
    loanNumbers = self.loans_from_json()
    for loanNumber in loanNumbers:
      dupLoanNumber = self.clean_loan(str(loanNumber))
      if dupLoanNumber:
        loansWithDuplicates.append(dupLoanNumber)
        
    # if loansWithDuplicates:
    #   print(f'Loans with duplicate clients: {len(loansWithDuplicates)}')
    #   with open(f"/Users/BRadhakrishnan/Documents/repo/ql-personal/notebook/python/remove-dups/loans4.json", "w") as outfile:
    #     serialized = json.dump(loansWithDuplicates, outfile, indent=4 * ' ')
      
          
  def clean_loan(self, loanNumber):
    print(f'Starting Clean up on {loanNumber}')
    
    clients = self.get_clients(loanNumber)
    duplicates = self.__get_duplicates(clients)
    if duplicates:
      self.__backup_deleted(list(duplicates), loanNumber)
      for clientId in duplicates:
        self.remove(loanNumber, clientId)

      #print(f'found duplicates for {loanNumber}')
      return loanNumber
      #print(f"Loans With Duplicates: {loanNumber}")
    
    #print('Completed Clean up')
  def loans_from_json(self):
    file = open(self.fileName) 
    data = json.load(file)
    return data
  
  def loans_from_csv(self):
    reader = pd.read_csv(self.fileName, delimiter= ',', iterator= True)
    for df in reader:
      yield df.iloc[:, 0].tolist()
      
  def __backup(self, item, fileName):
    with open(f"/Users/BRadhakrishnan/Documents/repo/ql-personal/notebook/python/remove-dups/backup/{fileName}.json", "w") as outfile:
      serialized = json.dump(item, outfile, indent=4 * ' ')
    
  def __backup_deleted(self, item, fileName):
    with open(f"/Users/BRadhakrishnan/Documents/repo/ql-personal/notebook/python/remove-dups/deleted/{fileName}.json", "w") as outfile:
      serialized = json.dump(item, outfile, indent=4 * ' ')
    
  def get_clients(self, loanNumber):
    clients = []
    #print(f"Get Clients for loan: {loanNumber}")
    TABLE_NAME = "mortgageclient-data-prod-206763"
    dynamodb = boto3.resource(
        'dynamodb', region_name="us-east-2", verify=False)
    table = dynamodb.Table(TABLE_NAME)
    dynamoResponse = table.query(
        KeyConditionExpression=Key('LoanIdentifier').eq(str(loanNumber)) & Key('SortKey').begins_with('PI#'))
    
    if dynamoResponse:
        items = dynamoResponse['Items']
        self.__backup(items, loanNumber)
        for count, item in enumerate(items):
            ssn = item['SSN'] if 'SSN' in item else '' 
            firstName = item["FirstName"]
            lastName = item["LastName"]
            isPrimary = item['IsPrimary']
            isActive = False if item['IsDeleted'] == True else True
            clientId = item['ClientUID']
            gcid = item['GCID'] if 'GCID' in item else ''
            client = Client(clientId, gcid, ssn, firstName, lastName, isPrimary, isActive)
            clients.append(client)
    return clients
            
  def __get_duplicates(self,clients):
    duplicates = set()
    if clients:
      activeClients = list(filter(lambda client: client.isActive == True and client.gcid and client.ssn, clients))
      inActiveClients = list(filter(lambda client: not client.isActive, clients))
      inActiveSSNClients = list(filter(lambda client: not client.isActive and client.ssn, clients))
      inValidClients = list(filter(lambda client: not client.ssn, inActiveClients))
      invalidActiveClients = list(filter(lambda client: client.isActive == True and not client.ssn, clients))
      
      #Invalid Clients
      # for client in inValidClients:
      #   duplicates.add(client.clientId)
        
      # for client in invalidActiveClients:
      #   duplicates.add(client.clientId)
        
      visited = set()
      for client in inActiveSSNClients:
        if client.clientId in visited:
          continue
        inActiveButDups = [x for x in inActiveSSNClients if x.clientId !=
                       client.clientId and x.ssn == client.ssn]
        for x in inActiveButDups:
          visited.add(x.clientId)
          duplicates.add(x.clientId)
          
      for client in activeClients:
        inActiveDups = [x for x in inActiveClients if x.clientId !=
         client.clientId and x.gcid == client.gcid]
        for iad in inActiveDups:
          duplicates.add(iad.clientId)
          
      visited.clear()
      for client in activeClients:
        if client.clientId in visited:
          continue
        activeButDuplicates = [x for x in activeClients if x.clientId != client.clientId and x.gcid == client.gcid]
        for abd in activeButDuplicates:
          visited.add(abd.clientId)
          duplicates.add(abd.clientId)
      
    return duplicates
            
  def remove(self,loanNumber, clientId):
    TABLE_NAME = 'mortgageclient-data-prod-206763'
    sortKey = f"PI#{clientId}"
    dynamodb = boto3.resource(
        'dynamodb', region_name="us-east-2", verify=False)
    table = dynamodb.Table(TABLE_NAME)
    table.delete_item(Key={'LoanIdentifier': loanNumber,
                           'SortKey': sortKey
                           })
    print(f"Loan {loanNumber}, clientId {clientId} Removed")
    
    
process = RemoveDups(
    '/Users/BRadhakrishnan/Documents/repo/ql-personal/notebook/python/remove-dups/loan.json')
process.start_cleanup()
# loanNumbers = process.loans_from_json()
# for loanNumber in loanNumbers:
#   print(loanNumber)
#process.clean_loan('3520947959')
#process.remove('3521480935', '36a25c388ec54d859cf7e6241df2718d')
# clients = process.get_clients('3521307939')
# for client in clients:
#   print(client.clientId)
# Out:
# Starting Clean up Process on List
# Starting Clean up on 3521073009
# Starting Clean up on 3521216651
# Starting Clean up on 3521311219
# Starting Clean up on 3520745262
# Starting Clean up on 3521282619
# Starting Clean up on 3521268640
# Starting Clean up on 3521256697
# Starting Clean up on 3521186007
# Starting Clean up on 3521317084
# Loan 3521317084, clientId 9c54da0eb57a4b549286ecf3125a42c7 Removed
# Starting Clean up on 3520187752
# Starting Clean up on 3521269024
# Starting Clean up on 3521317868
# Starting Clean up on 3521307667
# Starting Clean up on 3521266496
# Starting Clean up on 3521303681
# Starting Clean up on 3521263522
# Starting Clean up on 3521200670
# Starting Clean up on 3521236023
# Starting Clean up on 3521283653
# Starting Clean up on 3521283576
# Starting Clean up on 3521006612
# Starting Clean up on 3521309884
# Starting Clean up on 3521134651
# Starting Clean up on 3521167649
# Starting Clean up on 3521306346
# Starting Clean up on 3521276284
# Starting Clean up on 3521073648
# Starting Clean up on 3521307189
# Starting Clean up on 3521284430
# Starting Clean up on 3521303742
# Starting Clean up on 3520770626
# Starting Clean up on 3521269785
# Starting Clean up on 3521092206
# Starting Clean up on 3521275874
# Starting Clean up on 3520584044
# Starting Clean up on 3521299048
# Starting Clean up on 3521310213
# Starting Clean up on 3521305333
# Starting Clean up on 3521129919
# Loan 3521129919, clientId e0f48aaece2843a3a07f66b6609da953 Removed
# Starting Clean up on 3521309223
# Starting Clean up on 3521304747
# Starting Clean up on 3521254405
# Starting Clean up on 3521298484
# Starting Clean up on 3520976319
# Starting Clean up on 3521310030
# Starting Clean up on 3521304002
# Starting Clean up on 3521186180
# Starting Clean up on 3521269156
# Starting Clean up on 3521317613
# Loan 3521317613, clientId f8177aad2fa7428197138ed27e3e2acb Removed
# Starting Clean up on 3521273907
# Starting Clean up on 3521308045
# Starting Clean up on 3521186059
# Starting Clean up on 3521306999
# Starting Clean up on 3521218114
# Starting Clean up on 3520881118
# Starting Clean up on 3521309684
# Starting Clean up on 3521156513
# Loan 3521156513, clientId 0c47b8b591cb4464bd29b97f77541e1f Removed
# Loan 3521156513, clientId b9956266a8314ccb9e5bf3bd73914d2d Removed
# Loan 3521156513, clientId 0205ba48a4e340f2991ceb74ba579b2f Removed
# Starting Clean up on 3521310180
# Starting Clean up on 3521304838
# Starting Clean up on 3521305633
# Starting Clean up on 3521309868
# Starting Clean up on 3521197130
# Starting Clean up on 3521310300
# Starting Clean up on 3521307165
# Starting Clean up on 3521265503
# Starting Clean up on 3521231335
# Starting Clean up on 3521085194
# Starting Clean up on 3520929423
# Starting Clean up on 3521260522
# Starting Clean up on 3521205252
# Starting Clean up on 3521316644
# Loan 3521316644, clientId 848fef702ebc466bbfb61618d967c7d7 Removed
# Loan 3521316644, clientId 0063e82e517540f69ffddcb3a04a61ee Removed
# Starting Clean up on 3521310038
# Starting Clean up on 3521308539
# Starting Clean up on 3521263276
# Starting Clean up on 3521305891
# Starting Clean up on 3521247496
# Starting Clean up on 3521305870
# Starting Clean up on 3521307100
# Starting Clean up on 3521303887
# Starting Clean up on 3521275077
# Starting Clean up on 3521303689
# Starting Clean up on 3521268729
# Starting Clean up on 3521310157
# Starting Clean up on 3521309374
# Starting Clean up on 3521195609
# Starting Clean up on 3521270149
# Starting Clean up on 3521193754
# Starting Clean up on 3521207127
# Starting Clean up on 3521197642
# Starting Clean up on 3520999094
# Starting Clean up on 3521303283
# Starting Clean up on 3521304941
# Starting Clean up on 3521309328
# Starting Clean up on 3520380977
# Starting Clean up on 3521307603
# Starting Clean up on 3521197236
# Starting Clean up on 3521283618
# Starting Clean up on 3521167728
# Starting Clean up on 3520811376
# Starting Clean up on 3521308003
# Starting Clean up on 3520324849
# Starting Clean up on 3521205327
# Starting Clean up on 3521308523
# Starting Clean up on 3521260072
# Starting Clean up on 3521269125
# Starting Clean up on 3521240670
# Starting Clean up on 3521308570
# Starting Clean up on 3521306094
# Starting Clean up on 3521218514
# Starting Clean up on 3521311556
# Starting Clean up on 3521269641
# Loan 3521269641, clientId 3a50bcf1b56e44c19ee81fbc19a2ccb7 Removed
# Loan 3521269641, clientId 4704291757b54c53bb6982c32b00e32c Removed
# Loan 3521269641, clientId 163e75e07a4b4a83a501e82f55eeeb9e Removed
# Loan 3521269641, clientId 6ca009398bab443e978bed9d087ccca2 Removed
# Loan 3521269641, clientId 6d43944a9e4d415eba9ec4c2d07b899c Removed
# Loan 3521269641, clientId 3a0ce0e83d2f4b05ad20e3f84f57c72f Removed
# Loan 3521269641, clientId a052f0efdaa848e4b489ebca3c525181 Removed
# Starting Clean up on 3521316943
# Loan 3521316943, clientId f58fed8de19a48c3976377f8d74aa92e Removed
# Starting Clean up on 3521307306
# Starting Clean up on 3521310013
# Starting Clean up on 3521308453
# Starting Clean up on 3521108573
# Starting Clean up on 3521078024
# Starting Clean up on 3521237492
# Starting Clean up on 3521148161
# Starting Clean up on 3521310595
# Starting Clean up on 3521305990
# Starting Clean up on 3521310457
# Starting Clean up on 3521317249
# Starting Clean up on 3521279504
# Starting Clean up on 3521311910
# Starting Clean up on 3521267590
# Loan 3521267590, clientId 2bea43f46e484cc3b0319f2e56d42173 Removed
# Loan 3521267590, clientId 08eb35bb7f8648cdac3cb57bc8d8e54d Removed
# Loan 3521267590, clientId 7fe5d94fa2fe402bbee2a1ac507d29df Removed
# Loan 3521267590, clientId 8d12559acc294d49a0deece2b80cc2dc Removed
# Loan 3521267590, clientId ffcf9ebd70494a84a596dfe5ade51b36 Removed
# Loan 3521267590, clientId 7780358c2bfc4ecaaf39c15682c42296 Removed
# Loan 3521267590, clientId 45fe363b2a284a308bcf3a64c3e39b24 Removed
# Loan 3521267590, clientId bbec08042d7c4840af57975d41d5a653 Removed
# Loan 3521267590, clientId e281622052074a4f976ee15b836011a4 Removed
# Loan 3521267590, clientId fa06689976f7418aade952a3ff041b93 Removed
# Loan 3521267590, clientId 3fce8b3feb354b6e83f5be00ca2f5c39 Removed
# Loan 3521267590, clientId 4ff40719ad804c80baab6e6376273429 Removed
# Loan 3521267590, clientId c0f22bb8af16433fa471d77ba24a1287 Removed
# Loan 3521267590, clientId a412b3ffacb8401a8c3767c154de7590 Removed
# Starting Clean up on 3521304013
# Starting Clean up on 3520959309
# Starting Clean up on 3521311356
# Starting Clean up on 3521312053
# Starting Clean up on 3521298332
# Starting Clean up on 3521306306
# Starting Clean up on 3520946941
# Starting Clean up on 3521305709
# Starting Clean up on 3521269077
# Starting Clean up on 3521270448
# Starting Clean up on 3521267214
# Starting Clean up on 3521308682
# Starting Clean up on 3521311167
# Starting Clean up on 3521305851
# Starting Clean up on 3521149561
# Starting Clean up on 3521268975
# Starting Clean up on 3521079559
# Starting Clean up on 3520891501
# Starting Clean up on 3521046395
# Starting Clean up on 3521192036
# Starting Clean up on 3521309711
# Starting Clean up on 3521310426
# Starting Clean up on 3521267408
# Starting Clean up on 3521303323
# Starting Clean up on 3521311538
# Starting Clean up on 3521311275
# Starting Clean up on 3521298794
# Starting Clean up on 3520948299
# Starting Clean up on 3521311370
# Starting Clean up on 3521253167
# Starting Clean up on 3521313165
# Starting Clean up on 3521307459
# Starting Clean up on 3521137079
# Starting Clean up on 3521267068
# Starting Clean up on 3521045433
# Starting Clean up on 3519317965
# Starting Clean up on 3520929837
# Starting Clean up on 3521311384
# Starting Clean up on 3521311924
# Starting Clean up on 3521265617
# Loan 3521265617, clientId 4b7c33a4322b4f4cb524111378f30e77 Removed
# Starting Clean up on 3521255937
# Loan 3521255937, clientId 4567b71b2f24475ea128555e4d6ce081 Removed
# Starting Clean up on 3521267901
# Loan 3521267901, clientId b5142a6faad843bda51d737fbb132ea8 Removed
# Starting Clean up on 3521267369
# Loan 3521267369, clientId e787f5f84b604e528e2716d60ed48d5f Removed
# Loan 3521267369, clientId e55fd5e9172548708aaf6e7555ea22d8 Removed
# Starting Clean up on 3521256893
# Loan 3521256893, clientId 503ed7d3ec8d4b11b7a6ef487b622699 Removed
# Loan 3521256893, clientId 0bf50180a5594eb2a34dae193cace1bb Removed
# Starting Clean up on 3521162908
# Loan 3521162908, clientId d3d00bc82fbe47f8a4ed3237e54ff41b Removed
# Starting Clean up on 3521189019
# Loan 3521189019, clientId ef88a2b91a1d406aa08dbb4b1a30c3cf Removed
# Starting Clean up on 3521248345
# Loan 3521248345, clientId 8541118dff174dd0968bd9db8d889f77 Removed
